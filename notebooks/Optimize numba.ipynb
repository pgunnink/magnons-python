# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from magnons.amplitudes import AkBk, AkBkAngle
from magnons.energies import hamiltonian_AB, get_E_and_ev
from magnons.yig import J, S, mu, a
import numba

# %%
ky = 10**3
kz = 10**4
phi = np.radians(18)
alpha = np.radians(30)
N = 400
h = 2500 * mu
eps = a**(-2)
A, B = AkBkAngle(ky, kz, phi, alpha, N=N, J=J, S=S, h=h, mu=mu, eps=eps, a=a)
ham = hamiltonian_AB(A,B)
# Out:
# C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\amplitudes.py:77: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "AkBkAngle" failed type inference due to: Untyped global name 'Dkxx': cannot determine Numba type of <class 'type'>
#
# File "..\magnons\amplitudes.py", line 91:
# def AkBkAngle(ky,
#     <source elided>
#               Ng=4):
#     xx = Dkxx(eps=eps, a=a, mu=mu, Nr=Nr, Ng=Ng)
#     ^
#
#   @jit
# C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\amplitudes.py:77: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "AkBkAngle" failed type inference due to: Untyped global name 'Dkxx': cannot determine Numba type of <class 'type'>
#
# File "..\magnons\amplitudes.py", line 91:
# def AkBkAngle(ky,
#     <source elided>
#               Ng=4):
#     xx = Dkxx(eps=eps, a=a, mu=mu, Nr=Nr, Ng=Ng)
#     ^
#
#   @jit
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:178: NumbaWarning: Function "AkBkAngle" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "..\magnons\amplitudes.py", line 78:
# @jit
# def AkBkAngle(ky,
# ^
#
#   state.func_ir.loc))
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:187: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\magnons\amplitudes.py", line 78:
# @jit
# def AkBkAngle(ky,
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, state.func_ir.loc))
# C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\dipolar_sums.py:135: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "table" failed type inference due to: non-precise type pyobject
# [1] During: typing of argument at C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\dipolar_sums.py (140)
#
# File "..\magnons\dipolar_sums.py", line 140:
#     def table(self, ky, kz, N):
#         <source elided>
#         #     dtype=np.complex)
#         temp = self.run(np.arange(-N + 1, 1, 1) * self.a, ky, kz)
#         ^
#
#   @jit
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:178: NumbaWarning: Function "table" was compiled in object mode without forceobj=True.
#
# File "..\magnons\dipolar_sums.py", line 136:
#     @jit
#     def table(self, ky, kz, N):
#     ^
#
#   state.func_ir.loc))
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:187: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\magnons\dipolar_sums.py", line 136:
#     @jit
#     def table(self, ky, kz, N):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, state.func_ir.loc))
# C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\dipolar_sums.py:75: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "real_sum" failed type inference due to: Untyped global name 'isinstance': cannot determine Numba type of <class 'builtin_function_or_method'>
#
# File "..\magnons\dipolar_sums.py", line 77:
#     def real_sum(self, x, ky, kz):
#         if isinstance(x, float) or isinstance(x, int):
#         ^
#
#   @jit
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:178: NumbaWarning: Function "real_sum" was compiled in object mode without forceobj=True.
#
# File "..\magnons\dipolar_sums.py", line 76:
#     @jit
#     def real_sum(self, x, ky, kz):
#     ^
#
#   state.func_ir.loc))
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:187: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\magnons\dipolar_sums.py", line 76:
#     @jit
#     def real_sum(self, x, ky, kz):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, state.func_ir.loc))
# C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\dipolar_sums.py:31: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "misra" failed type inference due to: Untyped global name 'erfc': cannot determine Numba type of <class 'numpy.ufunc'>
#
# File "..\magnons\dipolar_sums.py", line 34:
# def misra(x):
#     <source elided>
#     return np.exp(-x) * (3 + 2 * x) / (2 * x**2) + 3 * np.sqrt(np.pi) * erfc(
#         np.sqrt(x)) / (4 * x**(5 / 2))
#         ^
#
#   @jit
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:178: NumbaWarning: Function "misra" was compiled in object mode without forceobj=True.
#
# File "..\magnons\dipolar_sums.py", line 32:
# @jit
# def misra(x):
# ^
#
#   state.func_ir.loc))
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:187: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\magnons\dipolar_sums.py", line 32:
# @jit
# def misra(x):
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, state.func_ir.loc))
# C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\dipolar_sums.py:100: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "recip_sum" failed type inference due to: Untyped global name 'isinstance': cannot determine Numba type of <class 'builtin_function_or_method'>
#
# File "..\magnons\dipolar_sums.py", line 102:
#     def recip_sum(self, x, ky, kz):
#         if isinstance(x, float) or isinstance(x, int):
#         ^
#
#   @jit
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:178: NumbaWarning: Function "recip_sum" was compiled in object mode without forceobj=True.
#
# File "..\magnons\dipolar_sums.py", line 101:
#     @jit
#     def recip_sum(self, x, ky, kz):
#     ^
#
#   state.func_ir.loc))
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:187: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\magnons\dipolar_sums.py", line 101:
#     @jit
#     def recip_sum(self, x, ky, kz):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, state.func_ir.loc))
# C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\dipolar_sums.py:135: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "table" failed type inference due to: non-precise type pyobject
# [1] During: typing of argument at C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\dipolar_sums.py (140)
#
# File "..\magnons\dipolar_sums.py", line 140:
#     def table(self, ky, kz, N):
#         <source elided>
#         #     dtype=np.complex)
#         temp = self.run(np.arange(-N + 1, 1, 1) * self.a, ky, kz)
#         ^
#
#   @jit
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:178: NumbaWarning: Function "table" was compiled in object mode without forceobj=True.
#
# File "..\magnons\dipolar_sums.py", line 136:
#     @jit
#     def table(self, ky, kz, N):
#     ^
#
#   state.func_ir.loc))
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:187: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\magnons\dipolar_sums.py", line 136:
#     @jit
#     def table(self, ky, kz, N):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, state.func_ir.loc))
# C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\dipolar_sums.py:75: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "real_sum" failed type inference due to: Untyped global name 'isinstance': cannot determine Numba type of <class 'builtin_function_or_method'>
#
# File "..\magnons\dipolar_sums.py", line 77:
#     def real_sum(self, x, ky, kz):
#         if isinstance(x, float) or isinstance(x, int):
#         ^
#
#   @jit
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:178: NumbaWarning: Function "real_sum" was compiled in object mode without forceobj=True.
#
# File "..\magnons\dipolar_sums.py", line 76:
#     @jit
#     def real_sum(self, x, ky, kz):
#     ^
#
#   state.func_ir.loc))
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:187: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\magnons\dipolar_sums.py", line 76:
#     @jit
#     def real_sum(self, x, ky, kz):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, state.func_ir.loc))
# C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\dipolar_sums.py:100: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "recip_sum" failed type inference due to: Untyped global name 'isinstance': cannot determine Numba type of <class 'builtin_function_or_method'>
#
# File "..\magnons\dipolar_sums.py", line 102:
#     def recip_sum(self, x, ky, kz):
#         if isinstance(x, float) or isinstance(x, int):
#         ^
#
#   @jit
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:178: NumbaWarning: Function "recip_sum" was compiled in object mode without forceobj=True.
#
# File "..\magnons\dipolar_sums.py", line 101:
#     @jit
#     def recip_sum(self, x, ky, kz):
#     ^
#
#   state.func_ir.loc))
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:187: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\magnons\dipolar_sums.py", line 101:
#     @jit
#     def recip_sum(self, x, ky, kz):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, state.func_ir.loc))
# C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\amplitudes.py:77: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "AkBkAngle" failed type inference due to: Use of unsupported NumPy function 'numpy.flip' or unsupported use of the function.
#
# File "..\magnons\amplitudes.py", line 128:
# def AkBkAngle(ky,
#     <source elided>
#     for i in range(N):
#         Atemp[i, :] -= np.flip(
#         ^
#
# [1] During: typing of get attribute at C:\Users\Gunni002\Dropbox\UU\Magnons\Python\magnons\magnons\amplitudes.py (128)
#
# File "..\magnons\amplitudes.py", line 128:
# def AkBkAngle(ky,
#     <source elided>
#     for i in range(N):
#         Atemp[i, :] -= np.flip(
#         ^
#
#   @jit
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:178: NumbaWarning: Function "AkBkAngle" was compiled in object mode without forceobj=True.
#
# File "..\magnons\amplitudes.py", line 127:
# def AkBkAngle(ky,
#     <source elided>
#
#     for i in range(N):
#     ^
#
#   state.func_ir.loc))
# C:\Users\Gunni002\AppData\Local\Continuum\miniconda3\lib\site-packages\numba\object_mode_passes.py:187: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\magnons\amplitudes.py", line 127:
# def AkBkAngle(ky,
#     <source elided>
#
#     for i in range(N):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, state.func_ir.loc))

# %%
E, U = np.linalg.eigh(A)
print(numba.typeof(U))
# Out:
# array(complex128, 2d, C)

# %%
print(numba.typeof(A.T.conj()))
# Out:
# array(complex128, 2d, F)

# %%
get_E_and_ev(A, B, True, 1)
# Out:
# (array([5.27548513e-17, 5.51861082e-17, 5.65422694e-17, 5.85452889e-17,
#         6.13341551e-17, 6.49045257e-17, 6.92522702e-17, 7.43735643e-17,
#         8.02648355e-17, 8.69233144e-17, 9.43468803e-17, 1.02534073e-16,
#         1.11483882e-16, 1.21195652e-16, 1.31668930e-16, 1.42903394e-16,
#         1.54898760e-16, 1.67654751e-16, 1.81171047e-16, 1.95447275e-16,
#         2.10482989e-16, 2.26277666e-16, 2.42830700e-16, 2.60141407e-16,
#         2.78209020e-16, 2.97032696e-16, 3.16611514e-16, 3.36944482e-16,
#         3.58030538e-16, 3.79868550e-16, 4.02457322e-16, 4.25795596e-16,
#         4.49882053e-16, 4.74715312e-16, 5.00293936e-16, 5.26616434e-16,
#         5.53681258e-16, 5.81486805e-16, 6.10031421e-16, 6.39313401e-16,
#         6.69330988e-16, 7.00082373e-16, 7.31565701e-16, 7.63779065e-16,
#         7.96720511e-16, 8.30388037e-16, 8.64779593e-16, 8.99893081e-16,
#         9.35726358e-16, 9.72277235e-16, 1.00954347e-15, 1.04752279e-15,
#         1.08621287e-15, 1.12561133e-15, 1.16571575e-15, 1.20652367e-15,
#         1.24803259e-15, 1.29023995e-15, 1.33314317e-15, 1.37673960e-15,
#         1.42102657e-15, 1.46600134e-15, 1.51166115e-15, 1.55800320e-15,
#         1.60502462e-15, 1.65272253e-15, 1.70109398e-15, 1.75013600e-15,
#         1.79984557e-15, 1.85021962e-15, 1.90125505e-15, 1.95294872e-15,
#         2.00529744e-15, 2.05829798e-15, 2.11194709e-15, 2.16624144e-15,
#         2.22117770e-15, 2.27675249e-15, 2.33296236e-15, 2.38980386e-15,
#         2.45927430e-14, 2.46197979e-14, 2.46461097e-14, 2.46716768e-14,
#         2.46964975e-14, 2.47205705e-14, 2.47438942e-14, 2.47664671e-14,
#         2.47882880e-14, 2.48093553e-14, 2.48296678e-14, 2.48492244e-14,
#         2.48680237e-14, 2.48860645e-14, 2.49033459e-14, 2.49198667e-14,
#         2.49356259e-14, 2.49506226e-14, 2.49648557e-14, 2.49783245e-14,
#         2.49910281e-14, 2.50029657e-14, 2.50141366e-14, 2.50245401e-14,
#         2.50341755e-14, 2.50430423e-14, 2.50511399e-14, 2.50584678e-14,
#         2.50650255e-14, 2.50708127e-14, 2.50758290e-14, 2.50800741e-14,
#         2.50835477e-14, 2.50862496e-14, 2.50881797e-14, 2.50893378e-14]),
#  array([[-4.80526689e-02-1.30080535e-02j, -7.11354306e-02-2.27097344e-02j,
#          -7.11364182e-02-1.85156907e-02j, ...,
#          -8.33051192e-04-5.53963524e-09j, -5.55374598e-04-3.69285416e-09j,
#          -2.77689440e-04-1.84635418e-09j],
#         [-4.80567257e-02-1.30072826e-02j, -7.11359937e-02-2.27066942e-02j,
#          -7.11234437e-02-1.85119348e-02j, ...,
#           2.49863115e-03+1.65045940e-08j,  1.66594679e-03+1.10034823e-08j,
#           8.33031202e-04+5.50186913e-09j],
#         [-4.80618678e-02-1.30050446e-02j, -7.11328137e-02-2.26992722e-02j,
#          -7.10931972e-02-1.85033384e-02j, ...,
#          -4.16282384e-03-2.73496646e-08j, -2.77610781e-03-1.82375651e-08j,
#          -1.38832152e-03-9.12011712e-09j],
#         ...,
#         [-5.01518633e-03+2.60542341e-03j,  9.02933785e-03-2.76562974e-03j,
#          -9.08670563e-03+2.29253167e-03j, ...,
#           1.40448322e-06+8.93303841e-11j, -9.36560677e-07-5.96601419e-11j,
#           4.68351836e-07+2.98206064e-11j],
#         [-5.01757633e-03+2.60732931e-03j,  9.03369918e-03-2.76967590e-03j,
#          -9.09447116e-03+2.29638163e-03j, ...,
#          -8.40043372e-07-8.52205526e-11j,  5.60056607e-07+5.67788146e-11j,
#          -2.80036679e-07-2.84203231e-11j],
#         [-5.02071570e-03+2.60880143e-03j,  9.03873914e-03-2.77266991e-03j,
#          -9.10119359e-03+2.29911207e-03j, ...,
#           2.96640810e-07+1.35874027e-10j, -1.97750004e-07-9.06268833e-11j,
#           9.88717738e-08+4.52853625e-11j]]))

# %% [markdown]
# Simple run, without numba optimizations:

# %%
# %timeit AkBkAngle(ky, kz, phi, alpha, N=N, J=J, S=S, h=h, mu=mu, eps=eps, a=a)
# Out:
# 432 ms ± 21.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit get_E_and_ev(A, B, True, 1)

# %% [markdown]
# Start optimizing

# %%
AkBkAngle(ky, kz, phi, alpha, N=N, J=J, S=S, h=h, mu=mu, eps=eps, a=a)

# %%
# %timeit AkBkAngle(ky, kz, phi, alpha, N=N, J=J, S=S, h=h, mu=mu, eps=eps, a=a)
